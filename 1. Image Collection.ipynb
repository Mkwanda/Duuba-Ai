# %% [markdown]
# # 1. Import Dependencies

# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\owner\desktop\machine learning\tfodcourse\cod\lib\site-packages (4.7.0.72)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\owner\desktop\machine learning\tfodcourse\cod\lib\site-packages (from opencv-python) (1.24.2)

# %%
# Import opencv
import cv2 

# Import uuid
import uuid

# Import Operating System
import os

# Import time
import time

# %% [markdown]
# # 2. Define Images to Collect

# %%
labels = ['wakanda','thumbsup', 'thumbsdown', 'thankyou', 'livelong']
number_imgs = 5

# %% [markdown]
# # 3. Setup Folders

# %%
IMAGES_PATH = os.path.join('Tensorflow', 'workspace', 'images', 'collectedimages')

# %%
if not os.path.exists(IMAGES_PATH):
    if os.name == 'posix':
        # !mkdir -p {IMAGES_PATH}
    if os.name == 'nt':
         # !mkdir {IMAGES_PATH}
for label in labels:
    path = os.path.join(IMAGES_PATH, label)
    if not os.path.exists(path):
        # !mkdir {path}

# %% [markdown]
# # 4. Capture Images

# %%
for label in labels:
    cap = cv2.VideoCapture(0)
    print('Collecting images for {}'.format(label))
    time.sleep(5)
    for imgnum in range(number_imgs):
        print('Collecting image {}'.format(imgnum))
        ret, frame = cap.read()
        imgname = os.path.join(IMAGES_PATH,label,label+'.'+'{}.jpg'.format(str(uuid.uuid1())))
        cv2.imwrite(imgname, frame)
        cv2.imshow('frame', frame)
        time.sleep(2)

        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
cap.release()
cv2.destroyAllWindows()
# Out:
# Collecting images for wakanda
# Collecting image 0
# Collecting image 1
# Collecting image 2
# Collecting image 3
# Collecting image 4
# Collecting images for thumbsup
# Collecting image 0
# Collecting image 1
# Collecting image 2
# Collecting image 3
# Collecting image 4
# Collecting images for thumbsdown
# Collecting image 0
# Collecting image 1
# Collecting image 2
# Collecting image 3
# Collecting image 4
# Collecting images for thankyou
# Collecting image 0
# Collecting image 1
# Collecting image 2
# Collecting image 3
# Collecting image 4
# Collecting images for livelong
# Collecting image 0
# Collecting image 1
# Collecting image 2
# Collecting image 3
# Collecting image 4

# %% [markdown]
# # 5. Image Labelling

# %%
# !pip install --upgrade pyqt5 lxml
# Out:
# Requirement already satisfied: pyqt5 in c:\users\owner\desktop\machine learning\tfodcourse\cod\lib\site-packages (5.15.9)
# Requirement already satisfied: lxml in c:\users\owner\desktop\machine learning\tfodcourse\cod\lib\site-packages (4.9.2)
# Requirement already satisfied: PyQt5-sip<13,>=12.11 in c:\users\owner\desktop\machine learning\tfodcourse\cod\lib\site-packages (from pyqt5) (12.11.1)
# Requirement already satisfied: PyQt5-Qt5>=5.15.2 in c:\users\owner\desktop\machine learning\tfodcourse\cod\lib\site-packages (from pyqt5) (5.15.2)

# %%
LABELING_PATH = os.path.join('Tensorflow', 'labelimg')

# %%
if not os.path.exists(LABELING_PATH):
    # !mkdir {LABELING_PATH}
    # !git clone https://github.com/tzutalin/labelImg {LABELING_PATH}

# %%
if os.name == 'posix':
    # !cd {LABELING_PATH} && make qt5py3
if os.name =='nt':
    # !cd {LABELING_PATH} && pyrcc5 -o libs/resources.py resources.qrc

# %%
#Open lebeling APP
# !cd {LABELING_PATH} && python labelImg.py
# Out:
# Image:C:\Users\owner\Desktop\Machine Learning\TFODCourse\Tensorflow\workspace\images\collectedimages\livelong\livelong.e6b75e78-d601-11ed-b4f8-e06995e54f59.jpg -> Annotation:C:/Users/owner/Desktop/Machine Learning/TFODCourse/Tensorflow/workspace/images/collectedimages/livelong\livelong.e6b75e78-d601-11ed-b4f8-e06995e54f59.xml
# Image:C:\Users\owner\Desktop\Machine Learning\TFODCourse\Tensorflow\workspace\images\collectedimages\livelong\livelong.e7eb48b5-d601-11ed-8e3f-e06995e54f59.jpg -> Annotation:C:/Users/owner/Desktop/Machine Learning/TFODCourse/Tensorflow/workspace/images/collectedimages/livelong\livelong.e7eb48b5-d601-11ed-8e3f-e06995e54f59.xml
# Image:C:\Users\owner\Desktop\Machine Learning\TFODCourse\Tensorflow\workspace\images\collectedimages\livelong\livelong.e91f5faf-d601-11ed-8a87-e06995e54f59.jpg -> Annotation:C:/Users/owner/Desktop/Machine Learning/TFODCourse/Tensorflow/workspace/images/collectedimages/livelong\livelong.e91f5faf-d601-11ed-8a87-e06995e54f59.xml
# Image:C:\Users\owner\Desktop\Machine Learning\TFODCourse\Tensorflow\workspace\images\collectedimages\livelong\livelong.ea550ad2-d601-11ed-96d7-e06995e54f59.jpg -> Annotation:C:/Users/owner/Desktop/Machine Learning/TFODCourse/Tensorflow/workspace/images/collectedimages/livelong\livelong.ea550ad2-d601-11ed-96d7-e06995e54f59.xml
# Image:C:\Users\owner\Desktop\Machine Learning\TFODCourse\Tensorflow\workspace\images\collectedimages\livelong\livelong.eb8ade1c-d601-11ed-9bf6-e06995e54f59.jpg -> Annotation:C:/Users/owner/Desktop/Machine Learning/TFODCourse/Tensorflow/workspace/images/collectedimages/livelong\livelong.eb8ade1c-d601-11ed-9bf6-e06995e54f59.xml
# Image:C:\Users\owner\Desktop\Machine Learning\TFODCourse\Tensorflow\workspace\images\collectedimages\thankyou\thankyou.dced6a39-d601-11ed-aa18-e06995e54f59.jpg -> Annotation:C:/Users/owner/Desktop/Machine Learning/TFODCourse/Tensorflow/workspace/images/collectedimages/thankyou\thankyou.dced6a39-d601-11ed-aa18-e06995e54f59.xml
# Image:C:\Users\owner\Desktop\Machine Learning\TFODCourse\Tensorflow\workspace\images\collectedimages\thankyou\thankyou.de21a8ac-d601-11ed-b50d-e06995e54f59.jpg -> Annotation:C:/Users/owner/Desktop/Machine Learning/TFODCourse/Tensorflow/workspace/images/collectedimages/thankyou\thankyou.de21a8ac-d601-11ed-b50d-e06995e54f59.xml
# Image:C:\Users\owner\Desktop\Machine Learning\TFODCourse\Tensorflow\workspace\images\collectedimages\thankyou\thankyou.e1c285cc-d601-11ed-a575-e06995e54f59.jpg -> Annotation:C:/Users/owner/Desktop/Machine Learning/TFODCourse/Tensorflow/workspace/images/collectedimages/thankyou\thankyou.e1c285cc-d601-11ed-a575-e06995e54f59.xml
# Image:C:\Users\owner\Desktop\Machine Learning\TFODCourse\Tensorflow\workspace\images\collectedimages\thankyou\thankyou.e08c842c-d601-11ed-818c-e06995e54f59.jpg -> Annotation:C:/Users/owner/Desktop/Machine Learning/TFODCourse/Tensorflow/workspace/images/collectedimages/thankyou\thankyou.e08c842c-d601-11ed-818c-e06995e54f59.xml
# Image:C:\Users\owner\Desktop\Machine Learning\TFODCourse\Tensorflow\workspace\images\collectedimages\thumbsdown\thumbsdown.c3a0f744-d600-11ed-bc56-e06995e54f59.jpg -> Annotation:C:/Users/owner/Desktop/Machine Learning/TFODCourse/Tensorflow/workspace/images/collectedimages/thumbsdown\thumbsdown.c3a0f744-d600-11ed-bc56-e06995e54f59.xml
# Image:C:\Users\owner\Desktop\Machine Learning\TFODCourse\Tensorflow\workspace\images\collectedimages\thumbsdown\thumbsdown.d32ac32f-d601-11ed-b45b-e06995e54f59.jpg -> Annotation:C:/Users/owner/Desktop/Machine Learning/TFODCourse/Tensorflow/workspace/images/collectedimages/thumbsdown\thumbsdown.d32ac32f-d601-11ed-b45b-e06995e54f59.xml
# Image:C:\Users\owner\Desktop\Machine Learning\TFODCourse\Tensorflow\workspace\images\collectedimages\thumbsdown\thumbsdown.d595eaa4-d601-11ed-a643-e06995e54f59.jpg -> Annotation:C:/Users/owner/Desktop/Machine Learning/TFODCourse/Tensorflow/workspace/images/collectedimages/thumbsdown\thumbsdown.d595eaa4-d601-11ed-a643-e06995e54f59.xml
# Image:C:\Users\owner\Desktop\Machine Learning\TFODCourse\Tensorflow\workspace\images\collectedimages\thumbsdown\thumbsdown.d801a0e2-d601-11ed-bbba-e06995e54f59.jpg -> Annotation:C:/Users/owner/Desktop/Machine Learning/TFODCourse/Tensorflow/workspace/images/collectedimages/thumbsdown\thumbsdown.d801a0e2-d601-11ed-bbba-e06995e54f59.xml
# Image:C:\Users\owner\Desktop\Machine Learning\TFODCourse\Tensorflow\workspace\images\collectedimages\thumbsdown\thumbsdown.d4607c73-d601-11ed-aa93-e06995e54f59.jpg -> Annotation:C:/Users/owner/Desktop/Machine Learning/TFODCourse/Tensorflow/workspace/images/collectedimages/thumbsdown\thumbsdown.d4607c73-d601-11ed-aa93-e06995e54f59.xml
# Image:C:\Users\owner\Desktop\Machine Learning\TFODCourse\Tensorflow\workspace\images\collectedimages\thumbsup\thumbsup.c96da93f-d601-11ed-b9e2-e06995e54f59.jpg -> Annotation:C:/Users/owner/Desktop/Machine Learning/TFODCourse/Tensorflow/workspace/images/collectedimages/thumbsup\thumbsup.c96da93f-d601-11ed-b9e2-e06995e54f59.xml
# Image:C:\Users\owner\Desktop\Machine Learning\TFODCourse\Tensorflow\workspace\images\collectedimages\thumbsup\thumbsup.bc3c6163-d600-11ed-984c-e06995e54f59.jpg -> Annotation:C:/Users/owner/Desktop/Machine Learning/TFODCourse/Tensorflow/workspace/images/collectedimages/thumbsup\thumbsup.bc3c6163-d600-11ed-984c-e06995e54f59.xml
# Image:C:\Users\owner\Desktop\Machine Learning\TFODCourse\Tensorflow\workspace\images\collectedimages\thumbsup\thumbsup.bc3c6163-d600-11ed-984c-e06995e54f59.jpg -> Annotation:C:/Users/owner/Desktop/Machine Learning/TFODCourse/Tensorflow/workspace/images/collectedimages/thumbsup\thumbsup.bc3c6163-d600-11ed-984c-e06995e54f59.xml
# Image:C:\Users\owner\Desktop\Machine Learning\TFODCourse\Tensorflow\workspace\images\collectedimages\thumbsup\thumbsup.caa20cca-d601-11ed-9411-e06995e54f59.jpg -> Annotation:C:/Users/owner/Desktop/Machine Learning/TFODCourse/Tensorflow/workspace/images/collectedimages/thumbsup\thumbsup.caa20cca-d601-11ed-9411-e06995e54f59.xml
# Image:C:\Users\owner\Desktop\Machine Learning\TFODCourse\Tensorflow\workspace\images\collectedimages\thumbsup\thumbsup.cd0d75ba-d601-11ed-85d6-e06995e54f59.jpg -> Annotation:C:/Users/owner/Desktop/Machine Learning/TFODCourse/Tensorflow/workspace/images/collectedimages/thumbsup\thumbsup.cd0d75ba-d601-11ed-85d6-e06995e54f59.xml
# Image:C:\Users\owner\Desktop\Machine Learning\TFODCourse\Tensorflow\workspace\images\collectedimages\thumbsup\thumbsup.ce43350b-d601-11ed-a327-e06995e54f59.jpg -> Annotation:C:/Users/owner/Desktop/Machine Learning/TFODCourse/Tensorflow/workspace/images/collectedimages/thumbsup\thumbsup.ce43350b-d601-11ed-a327-e06995e54f59.xml
# Image:C:\Users\owner\Desktop\Machine Learning\TFODCourse\Tensorflow\workspace\images\collectedimages\wakanda\wakanda.b26e0e36-d600-11ed-990e-e06995e54f59.jpg -> Annotation:C:/Users/owner/Desktop/Machine Learning/TFODCourse/Tensorflow/workspace/images/collectedimages/wakanda\wakanda.b26e0e36-d600-11ed-990e-e06995e54f59.xml
# Image:C:\Users\owner\Desktop\Machine Learning\TFODCourse\Tensorflow\workspace\images\collectedimages\wakanda\wakanda.bfa757bc-d601-11ed-9a82-e06995e54f59.jpg -> Annotation:C:/Users/owner/Desktop/Machine Learning/TFODCourse/Tensorflow/workspace/images/collectedimages/wakanda\wakanda.bfa757bc-d601-11ed-9a82-e06995e54f59.xml
# Image:C:\Users\owner\Desktop\Machine Learning\TFODCourse\Tensorflow\workspace\images\collectedimages\wakanda\wakanda.c0dfecc0-d601-11ed-996b-e06995e54f59.jpg -> Annotation:C:/Users/owner/Desktop/Machine Learning/TFODCourse/Tensorflow/workspace/images/collectedimages/wakanda\wakanda.c0dfecc0-d601-11ed-996b-e06995e54f59.xml
# Image:C:\Users\owner\Desktop\Machine Learning\TFODCourse\Tensorflow\workspace\images\collectedimages\wakanda\wakanda.c47e5a8a-d601-11ed-b59b-e06995e54f59.jpg -> Annotation:C:/Users/owner/Desktop/Machine Learning/TFODCourse/Tensorflow/workspace/images/collectedimages/wakanda\wakanda.c47e5a8a-d601-11ed-b59b-e06995e54f59.xml
# Image:C:\Users\owner\Desktop\Machine Learning\TFODCourse\Tensorflow\workspace\images\collectedimages\wakanda\wakanda.c349a77b-d601-11ed-998e-e06995e54f59.jpg -> Annotation:C:/Users/owner/Desktop/Machine Learning/TFODCourse/Tensorflow/workspace/images/collectedimages/wakanda\wakanda.c349a77b-d601-11ed-998e-e06995e54f59.xml
# Image:C:\Users\owner\Desktop\Machine Learning\TFODCourse\Tensorflow\workspace\images\collectedimages\thankyou\thankyou.df571adb-d601-11ed-a270-e06995e54f59.jpg -> Annotation:C:/Users/owner/Desktop/Machine Learning/TFODCourse/Tensorflow/workspace/images/collectedimages/thankyou\thankyou.df571adb-d601-11ed-a270-e06995e54f59.xml
# Image:C:\Users\owner\Desktop\Machine Learning\TFODCourse\Cocoa\Tensorflow\workspace\images\collectedimages\infected\1-s2.0-S0885576518303278-gr8.jpg -> Annotation:C:/Users/owner/Desktop/Machine Learning/TFODCourse/Cocoa/Tensorflow/workspace/images/collectedimages/infected\1-s2.0-S0885576518303278-gr8.xml
# Image:C:\Users\owner\Desktop\Machine Learning\TFODCourse\Cocoa\Tensorflow\workspace\images\collectedimages\infected\2-Figure1-1.png -> Annotation:C:/Users/owner/Desktop/Machine Learning/TFODCourse/Cocoa/Tensorflow/workspace/images/collectedimages/infected\2-Figure1-1.xml
# Image:C:\Users\owner\Desktop\Machine Learning\TFODCourse\Cocoa\Tensorflow\workspace\images\collectedimages\infected\3CF129AA-13EB-4DFC-B7CD-E1A26BA8AAD3.JPG.jpg -> Annotation:C:/Users/owner/Desktop/Machine Learning/TFODCourse/Cocoa/Tensorflow/workspace/images/collectedimages/infected\3CF129AA-13EB-4DFC-B7CD-E1A26BA8AAD3.JPG.xml
# Image:C:\Users\owner\Desktop\Machine Learning\TFODCourse\Cocoa\Tensorflow\workspace\images\collectedimages\infected\8fa870_bc2f0fd078584b27aa6133b891d528e9.jpg -> Annotation:C:/Users/owner/Desktop/Machine Learning/TFODCourse/Cocoa/Tensorflow/workspace/images/collectedimages/infected\8fa870_bc2f0fd078584b27aa6133b891d528e9.xml
# Image:C:\Users\owner\Desktop\Machine Learning\TFODCourse\Cocoa\Tensorflow\workspace\images\collectedimages\infected\55.2.6.JPG.jpg -> Annotation:C:/Users/owner/Desktop/Machine Learning/TFODCourse/Cocoa/Tensorflow/workspace/images/collectedimages/infected\55.2.6.JPG.xml
# Image:C:\Users\owner\Desktop\Machine Learning\TFODCourse\Cocoa\Tensorflow\workspace\images\collectedimages\infected\55.29.JPG.jpg -> Annotation:C:/Users/owner/Desktop/Machine Learning/TFODCourse/Cocoa/Tensorflow/workspace/images/collectedimages/infected\55.29.JPG.xml
# Cancel creation.
# Image:C:\Users\owner\Desktop\Machine Learning\TFODCourse\Cocoa\Tensorflow\workspace\images\collectedimages\infected\2004_04_news_fig2_sm.jpg -> Annotation:C:/Users/owner/Desktop/Machine Learning/TFODCourse/Cocoa/Tensorflow/workspace/images/collectedimages/infected\2004_04_news_fig2_sm.xml
# Image:C:\Users\owner\Desktop\Machine Learning\TFODCourse\Cocoa\Tensorflow\workspace\images\collectedimages\infected\4598574864_a1d225d065_b.jpg -> Annotation:C:/Users/owner/Desktop/Machine Learning/TFODCourse/Cocoa/Tensorflow/workspace/images/collectedimages/infected\4598574864_a1d225d065_b.xml
# Image:C:\Users\owner\Desktop\Machine Learning\TFODCourse\Cocoa\Tensorflow\workspace\images\collectedimages\infected\29398718150_0555d48b87_b.jpg -> Annotation:C:/Users/owner/Desktop/Machine Learning/TFODCourse/Cocoa/Tensorflow/workspace/images/collectedimages/infected\29398718150_0555d48b87_b.xml
# Image:C:\Users\owner\Desktop\Machine Learning\TFODCourse\Cocoa\Tensorflow\workspace\images\collectedimages\infected\c0076482-800px-wm.jpg -> Annotation:C:/Users/owner/Desktop/Machine Learning/TFODCourse/Cocoa/Tensorflow/workspace/images/collectedimages/infected\c0076482-800px-wm.xml
# Image:C:\Users\owner\Desktop\Machine Learning\TFODCourse\Cocoa\Tensorflow\workspace\images\collectedimages\healthy\01514f791fe2584a4556a7f0cfb1b937.jpg -> Annotation:C:/Users/owner/Desktop/Machine Learning/TFODCourse/Cocoa/Tensorflow/workspace/images/collectedimages/healthy\01514f791fe2584a4556a7f0cfb1b937.xml
# Image:C:\Users\owner\Desktop\Machine Learning\TFODCourse\Cocoa\Tensorflow\workspace\images\collectedimages\healthy\Cocoapods-300x229.jpg -> Annotation:C:/Users/owner/Desktop/Machine Learning/TFODCourse/Cocoa/Tensorflow/workspace/images/collectedimages/healthy\Cocoapods-300x229.xml
# Image:C:\Users\owner\Desktop\Machine Learning\TFODCourse\Cocoa\Tensorflow\workspace\images\collectedimages\healthy\focused_152091858-stock-photo-fresh-cacao-pods.jpg -> Annotation:C:/Users/owner/Desktop/Machine Learning/TFODCourse/Cocoa/Tensorflow/workspace/images/collectedimages/healthy\focused_152091858-stock-photo-fresh-cacao-pods.xml
# Image:C:\Users\owner\Desktop\Machine Learning\TFODCourse\Cocoa\Tensorflow\workspace\images\collectedimages\healthy\here-are-some-exceptional-benefits-of-cocoa.jpg -> Annotation:C:/Users/owner/Desktop/Machine Learning/TFODCourse/Cocoa/Tensorflow/workspace/images/collectedimages/healthy\here-are-some-exceptional-benefits-of-cocoa.xml
# Cancel creation.
# Image:C:\Users\owner\Desktop\Machine Learning\TFODCourse\Cocoa\Tensorflow\workspace\images\collectedimages\healthy\image18.jpeg -> Annotation:C:/Users/owner/Desktop/Machine Learning/TFODCourse/Cocoa/Tensorflow/workspace/images/collectedimages/healthy\image18.xml
# Image:C:\Users\owner\Desktop\Machine Learning\TFODCourse\Cocoa\Tensorflow\workspace\images\collectedimages\healthy\images38.jpg -> Annotation:C:/Users/owner/Desktop/Machine Learning/TFODCourse/Cocoa/Tensorflow/workspace/images/collectedimages/healthy\images38.xml
# Image:C:\Users\owner\Desktop\Machine Learning\TFODCourse\Cocoa\Tensorflow\workspace\images\collectedimages\healthy\images151.jpg -> Annotation:C:/Users/owner/Desktop/Machine Learning/TFODCourse/Cocoa/Tensorflow/workspace/images/collectedimages/healthy\images151.xml
# Image:C:\Users\owner\Desktop\Machine Learning\TFODCourse\Cocoa\Tensorflow\workspace\images\collectedimages\healthy\images207 (2).jpg -> Annotation:C:/Users/owner/Desktop/Machine Learning/TFODCourse/Cocoa/Tensorflow/workspace/images/collectedimages/healthy\images207 (2).xml
# Image:C:\Users\owner\Desktop\Machine Learning\TFODCourse\Cocoa\Tensorflow\workspace\images\collectedimages\healthy\images369.jpg -> Annotation:C:/Users/owner/Desktop/Machine Learning/TFODCourse/Cocoa/Tensorflow/workspace/images/collectedimages/healthy\images369.xml
# Image:C:\Users\owner\Desktop\Machine Learning\TFODCourse\Cocoa\Tensorflow\workspace\images\collectedimages\healthy\images411.jpg -> Annotation:C:/Users/owner/Desktop/Machine Learning/TFODCourse/Cocoa/Tensorflow/workspace/images/collectedimages/healthy\images411.xml
# libpng warning: iCCP: profile 'ICC Profile': 0h: PCS illuminant is not D50

# %% [markdown]
# # 6. Move them into a Training and Testing Partition

# %% [markdown]
# # OPTIONAL - 7. Compress them for Colab Training

# %%
TRAIN_PATH = os.path.join('Tensorflow', 'workspace', 'images', 'train')
TEST_PATH = os.path.join('Tensorflow', 'workspace', 'images', 'test')
ARCHIVE_PATH = os.path.join('Tensorflow', 'workspace', 'images', 'archive.tar.gz')

# %%
# !tar -czf {ARCHIVE_PATH} {TRAIN_PATH} {TEST_PATH}
