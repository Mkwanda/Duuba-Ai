# %%
# !pip install opencv-python
# Out:
# ...
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install opencv-python-headless
# Out:
# ...
#                                               0.0/38.0 MB ? eta -:--:--
#                                               0.0/38.0 MB 1.4 MB/s eta 0:00:28
#                                               0.1/38.0 MB 1.1 MB/s eta 0:00:37
#                                               0.1/38.0 MB 1.1 MB/s eta 0:00:36
#                                              0.2/38.0 MB 958.1 kB/s eta 0:00:40
#                                              0.2/38.0 MB 986.4 kB/s eta 0:00:39
#                                              0.3/38.0 MB 927.4 kB/s eta 0:00:41
#                                              0.3/38.0 MB 951.8 kB/s eta 0:00:40
#                                              0.3/38.0 MB 912.8 kB/s eta 0:00:42
#                                              0.4/38.0 MB 882.8 kB/s eta 0:00:43
#                                              0.4/38.0 MB 926.8 kB/s eta 0:00:41
#                                              0.5/38.0 MB 930.9 kB/s eta 0:00:41
# ...

# %%
# Import opencv
import cv2 

# Import unique uid
import uuid

# Import Operating System

import os


# Import time
import time

# %%
#2. Define Images to Collect

# %%
labels = ['healthyPod','infectedPod']
number_imgs = 10

# %%
#setup folders
IMAGES_PATH = os.path.join('Cocoa','Tensorflow', 'workspace', 'images', 'collectedimages')

# %%
if not os.path.exists(IMAGES_PATH):
    if os.name == 'posix':
        # !mkdir -p {IMAGES_PATH}
    if os.name == 'nt':
         # !mkdir {IMAGES_PATH}
for label in labels:
    path = os.path.join(IMAGES_PATH, label)
    if not os.path.exists(path):
        # !mkdir {path}

# %%
LABELING_PATH = os.path.join('Cocoa','Tensorflow', 'labelimg')

# %%
if not os.path.exists(LABELING_PATH):
    # !mkdir {LABELING_PATH}
    # !git clone https://github.com/tzutalin/labelImg {LABELING_PATH}

# %%
LABELING_PATH = os.path.join('cod','Lib','python3.10','site-packages','labelImg')

# %%
print (LABELING_PATH)
# Out:
# cod\Lib\python3.10\site-packages\labelImg

# %%
# !cd {LABELING_PATH}

# %%
# !pip install -r requirements/requirements-linux-python3.txt
# Out:
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements/requirements-linux-python3.txt'

# %%
if os.name == 'posix':
    # !cd {LABELING_PATH} 
    # !make qt5py3
    
if os.name =='nt':
    # !cd {LABELING_PATH} && pyrcc5 -o libs/resources.py resources.qrc

# %%
# !cd {LABELING_PATH} && make qt5py3
# Out:
# make: *** No rule to make target 'qt5py3'.  Stop.

# %%
#Open lebeling APP
# !cd {LABELING_PATH} && python labelImg.py

# %%
#TRAIN MODEL
